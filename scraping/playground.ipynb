# %%
import spacy as sp
from spacy.tokenizer import Tokenizer
import pandas as pd
import lyricsgenius as genius
import nltk
from nltk.corpus import stopwords
api = genius.Genius('Wjaaj3obfMqU5E2v7aIdSS-PyH7CcGCK_-i_tDf6qDxNqGRzc4u5maoWcpi6Pqba')

# %%
song_one = api.search_song("Chlorine")
song_two = api.search_song("STOOPID")
song_list = (song_one.lyrics, song_two.lyrics)
# Out:
# Searching for "Chlorine"...
# Done.
# Searching for "STOOPID"...
# Done.

# %%
song_lyrics_sets = []
for song in song_list:
    word_list = song.split()
    list_copy = word_list
    for idx in range(len(word_list)):
        word = word_list[idx]

        #remove punctuation '?' and '.'
        if word.find('?')!= -1:
            word_list[idx] = word.replace("?","")
        if word.find('.') != -1:
            word_list[idx] = word.replace(".","")

    words_to_remove = []
    for word in word_list:
        #remove all part of song headers i.e. [Intro] or [Chorus]
        if word.find('[') != -1:
            words_to_remove.append(word)
        elif word.find(']') != -1:
            words_to_remove.append(word)

    for word in words_to_remove:
        word_list.remove(word)
    word_set = set(word_list)
    song_lyrics_sets.append(word_set)

# %%
#format stop words as a list so we can remove stop words
stwords = stopwords.raw()
stopword_list = stwords.split()

# %%
#Remove stop words
words_to_remove = []
for lyrics_set in song_lyrics_sets:
    for lyric in lyrics_set:
        if lyric in stopword_list:
            words_to_remove.append(lyric)

words_to_remove = set(words_to_remove)
for lyrics_set in song_lyrics_sets:
    for word in words_to_remove:
        if word in lyrics_set:
            lyrics_set.remove(word)

# %%
#code from danielle
def findLyrics():
    rock = ["Imagine Dragons", "lovelytheband", "Panic! At The Disco", "Mumford & Sons", "Bad Wolves", "John Mayer", "twenty one pilots", "George Ezra", "Badflower"]
    latin = ["Nio García", "Luis Fonsi", "6ix9ine", "Nicky Jam", "Daddy Yankee", "Becky G", "Ozuna", "Shakira", "Bad Bunny", "Maluma"]
    hiphop = ["Juice WRLD", "Post Malone", "Drake", "Eminem", "Travis Scott", "Cardi B", "Kanye West", "Tyga", "Drake", "DJ Khaled"]
    country = ["Bebe Rexha","Florida Georgia Line","Dan & Shay","Luke Combs","Kane Brown","Old Dominion", "Russell Dickerson","Luke Bryan","Cole Swindell","Mitchell Tenpenny"]
    christian = ["Lauren Daigle", "Avril Lavigne","Cory Asbury","Hillsong Worship","for KING & COUNTRY", "Tauren Wells","Elevation Worship","TobyMac","Francesca Battiselli","MercyMe"]
    punk = ["Minor Threat","Black Flag","Descendents", "Fugazi","Bad Brains","Dead Kennedys","Rancid","Bad Religion", "Pennywise", "NOFX"]
    
    genres = [('rock',rock), ('latin',latin), ('hiphop',hiphop), ('country',country), ('christian',christian), ('punk',punk)]
    
    master = []
    
    for genre in genres:
        for artist in genre[1]:
            artist = api.search_artist(artist, max_songs=5)
            songList = artist.songs
            for song in songList:
                row = (song.lyrics, genre[0])
                master.append(row)
    return master


def test():
    rock = ["Bad Wolves", "lovelytheband"]
    genres = [('rock',rock)]
    master= []


    for genre in genres:
        for artist in genre[1]:
            artist = api.search_artist(artist, max_songs=5)
            songList = artist.songs
            for song in songList:
                row = (song.lyrics, genre[0])
                master.append(row)
    print("right before return master")
    return master

masterList = findLyrics()
print(masterList)
# Out:
# Searching for songs by Imagine Dragons...
#
# Song 1: "30 Lives"
# Song 2: "30 Lives (Original Demo)"
# Song 3: "All Eyes"
# Song 4: "All For You"
# Song 5: "America"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by lovelytheband...
#
# Song 1: "​alone time"
# Song 2: "​broken"
# Song 3: "​coachella"
# Song 4: "Don't Worry, You Will"
# Song 5: "​emotion"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Panic! At The Disco...
#
# Song 1: "A Fever You Can't Sweat Out Medley"
# Song 2: "All the Boys"
# Song 3: "Always"
# Song 4: "Back Around"
# Song 5: "BBC Radio 1 Biggest Weekend 2018 Setlist"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Mumford & Sons...
#
# Song 1: "After The Storm"
# Song 2: "Announcement of Hiatus"
# Song 3: "Awake My Soul"
# Song 4: "Awake My Soul - Live at Studio Brussel"
# Song 5: "Awake My Soul (Live from Red Rocks)"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Bad Wolves...
#
# Song 1: "Better The Devil"
# Song 2: "Hear Me Now"
# Song 3: "Jesus Slaves"
# Song 4: "Learn To Live"
# Song 5: "No Masters"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by John Mayer...
#
# Song 1: "3x5"
# Song 2: "3x5 - live in birmingham"
# Song 3: "3x5 - live in ohio"
# Song 4: "83"
# Song 5: "83 - live in philadlephia,pa & hartford, ct"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by twenty one pilots...
#
# Song 1: "2015 MTV Video Music Awards Performance"
# Song 2: "7 Acoustic Covers (Medley)"
# Song 3: "A Car, a Torch, a Death"
# Song 4: "Addict with a Pen"
# Song 5: "A Few Older Ones"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by George Ezra...
#
# Song 1: "All My Love"
# Song 2: "Angry Hill"
# Song 3: "Barcelona"
# Song 4: "Benjamin Twine"
# Song 5: "Blame It On Me"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Badflower...
#
# Song 1: "Animal"
# Song 2: "Drop Dead"
# Song 3: "Ghost"
# Song 4: "Heroin"
# Song 5: "Let The Band Play"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Nio García...
#
# Song 1: "Borracho y Loco (Remix)"
# Song 2: "Castigo (Remix)"
# Song 3: "Escucha beba*"
# Song 4: "Igual O Peor"
# Song 5: "Infinitamente"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Luis Fonsi...
#
# Song 1: "Abrazar la vida"
# Song 2: "Amor prohibido"
# Song 3: "Amor secreto"
# Song 4: "Amor Secreto (Secret)"
# Song 5: "Anónimos"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by 6ix9ine...
#
# Song 1: "69"
# Song 2: "93"
# Song 3: "BEBE"
# Song 4: "BILLY"
# Song 5: "Blood Walk"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Nicky Jam...
#
# Song 1: "Adicta"
# Song 2: "Adicto"
# Song 3: "Amor Prohibido"
# Song 4: "Antioqueño"
# Song 5: "Buscando Placer"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Daddy Yankee...
#
# Song 1: "6 De Enero"
# Song 2: "After Party"
# Song 3: "Alerta Roja"
# Song 4: "All The Way Up (Spanish Remix)"
# Song 5: "A Lo Clásico"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Becky G...
#
# Song 1: "Alone In December"
# Song 2: "Becky From The Block"
# Song 3: "Bésame"
# Song 4: "Break A Sweat"
# Song 5: "Breaking Dawn"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Ozuna...
#
# Song 1: "Aunque Me Porté Mal"
# Song 2: "Aura"
# Song 3: "Bebé"
# Song 4: "Besos Mojados"
# Song 5: "Carita de Ángel"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Shakira...
#
# Song 1: "1968"
# Song 2: "23"
# Song 3: "Addicted to You"
# Song 4: "Amarillo"
# Song 5: "Animal City"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Bad Bunny...
#
# Song 1: "Alta Moda"
# Song 2: "Amorfoda"
# Song 3: "Bad Bunny: Problemas de un niño normal"
# Song 4: "Blockia"
# Song 5: "Chambea"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Maluma...
#
# Song 1: "23"
# Song 2: "Addicted"
# Song 3: "Aprovéchame"
# Song 4: "Borró Cassette"
# Song 5: "Carnaval"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Juice WRLD...
#
# Song 1: "30 Hours (Freestyle)"
# Song 2: "6"
# Song 3: "911"
# Song 4: "All Girls Are the Same"
# Song 5: "All Girls Are the Same (Live)"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Post Malone...
#
# Song 1: "40 Funk"
# Song 2: "92 Explorer"
# Song 3: "Another Cup"
# "August 26 [Tracklist + Album Art]" does not contain lyrics. Rejecting.
# Song 4: "Ball For Me"
# Song 5: "Better Now"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Drake...
#
# Song 1: "0 to 100 / The Catch Up"
# Song 2: "10 Bands"
# Song 3: "1Xtra Freestyle"
# Song 4: "2011 Juno Awards In Toronto"
# Song 5: "2016 MTV VMAs Vanguard Award Intro for Rihanna"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Eminem...
#
# Song 1: "1-833-2GET-REV (REVIVAL Voicemail)"
# Song 2: "1996 Underground Freestyle"
# Song 3: "1997 Freestyle Live at Wetlands, NYC"
# Song 4: "1997 Rap Olympics"
# Song 5: "1999"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Travis Scott...
#
# Song 1: "12 Disciples"
# Song 2: "16 Chapels"
# Song 3: "16 year old Home Studio Freestyle"
# Song 4: "3500"
# Song 5: "5% TINT"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Cardi B...
#
# Song 1: "Back It Up"
# Song 2: "Bartier Cardi"
# Song 3: "Be Careful"
# Song 4: "Best Life"
# Song 5: "Bickenhead"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Kanye West...
#
# Song 1: "18 Years"
# Song 2: "1996 Fat Beats Freestyle"
# Song 3: "2004 Tim Westwood Freestyle"
# "2013 Jimmy Kimmel Interview (Part 1)" does not contain lyrics. Rejecting.
# "2013 Jimmy Kimmel Interview (Part 2)" does not contain lyrics. Rejecting.
# Song 4: "2013 Yeezus Tour Dates"
# "2013 Zane Lowe BBC Radio Interview Part 1" does not contain lyrics. Rejecting.
# "2013 Zane Lowe BBC Radio Interview Part 2" does not contain lyrics. Rejecting.
# Song 5: "2014 Yeezus Tour Dates"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Tyga...
#
# Song 1: "09 Until"
# Song 2: "100's"
# Song 3: "10 Million $ Mortgage"
# Song 4: "1 of 1"
# Song 5: "2 AM"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Drake...
#
# Song 1: "0 to 100 / The Catch Up"
# Song 2: "10 Bands"
# Song 3: "1Xtra Freestyle"
# Song 4: "2011 Juno Awards In Toronto"
# Song 5: "2016 MTV VMAs Vanguard Award Intro for Rihanna"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by DJ Khaled...
#
# Song 1: "365"
# Song 2: "All I Do Is Win"
# Song 3: "All I Do Is Win (Remix)"
# Song 4: "A Million Lights"
# Song 5: "Ball"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Bebe Rexha...
#
# Song 1: "24/7"
# Song 2: "2 Souls on Fire"
# Song 3: "All Hands on Deck (Wasted Heart)"
# Song 4: "Apple"
# Song 5: "Atmosphere"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Florida Georgia Line...
#
# Song 1: "Angel"
# Song 2: "Anything Goes"
# Song 3: "Backwoods Beauty Queen"
# Song 4: "Black Tears"
# Song 5: "Bumpin' The Night"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Dan & Shay...
#
# Song 1: "19 You + Me"
# Song 2: "19 you + me - commentary"
# Song 3: "All Nighter"
# Song 4: "All to Myself"
# Song 5: "Alone Together"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Luke Combs...
#
# Song 1: "A Long Way"
# Song 2: "Beautiful Crazy"
# Song 3: "Beautiful Crazy (Ft. Leon Bridges)"
# Song 4: "Be Careful What You Wish For"
# Song 5: "Beer Can"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Kane Brown...
#
# Song 1: "Ain't No Stopping Us Now"
# Song 2: "Better Place"
# Song 3: "Body Like A Back Road (Cover)"
# Song 4: "Call the Sheriff"
# Song 5: "Closer"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Old Dominion...
#
# Song 1: "A Girl Is a Gun"
# Song 2: "Bad At Love"
# Song 3: "Beer Can in a Truck Bed"
# Song 4: "Be with Me"
# Song 5: "Break Up With Him"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Russell Dickerson...
#
# Song 1: "All Fall Down"
# Song 2: "Billions"
# Song 3: "Blue Tacoma"
# Song 4: "Every Little Thing"
# Song 5: "Float"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Luke Bryan...
#
# Song 1: "All My Friends Say"
# Song 2: "All My Friends Say (Unplugged)"
# Song 3: "Apologize"
# Song 4: "Are You Leaving With Him"
# Song 5: "Baby's on the Way"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Cole Swindell...
#
# Song 1: "20 In a Chevy"
# Song 2: "A Dozen Roses and a Six-Pack"
# Song 3: "Ain't Worth the Whiskey"
# Song 4: "All of It"
# Song 5: "Beer in the Headlights"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Mitchell Tenpenny...
#
# Song 1: "Alcohol You Later"
# Song 2: "Bitches"
# Song 3: "Drunk Me"
# Song 4: "If the Boot Fits (Acoustic)"
# Song 5: "Laid Back"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Lauren Daigle...
#
# Song 1: "Almost Human"
# Song 2: "Christmas Time Is Here"
# Song 3: "Come Alive (Dry Bones)"
# Song 4: "Come Alive (Dry Bones) [Deluxe Sessions]"
# Song 5: "Everything"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Avril Lavigne...
#
# Song 1: "17"
# Song 2: "4 Real"
# Song 3: "Adia"
# Song 4: "Alice"
# Song 5: "Alice (Extended Version)"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Cory Asbury...
#
# Song 1: "All Is for Your Glory (Live)"
# Song 2: "Always Faithful"
# Song 3: "Always Faithful (Prophetic Song)"
# Song 4: "Beautiful Savior"
# Song 5: "Born Again"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Hillsong Worship...
#
# Song 1: "Abba, Father"
# Song 2: "Across The Earth"
# Song 3: "Adonai"
# Song 4: "Alive In Us"
# Song 5: "All For Love"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by for KING & COUNTRY...
#
# Song 1: "Already Home"
# Song 2: "Amazing Grace"
# Song 3: "Amazing Grace (feat. Rebecca St. James)"
# Song 4: "​amen"
# Song 5: "Angels We Have Heard On High"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Tauren Wells...
#
# Song 1: "All About You"
# Song 2: "All My Love"
# Song 3: "God's Not Done With You"
# Song 4: "God's Not Done With You (Original Demo)"
# Song 5: "Hills and Valleys"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Elevation Worship...
#
# Song 1: "All Around The World"
# Song 2: "All My Hope"
# Song 3: "All Things New"
# Song 4: "Already Won"
# Song 5: "Amazed By You"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by TobyMac...
#
# Song 1: "Afterword"
# Song 2: "All In (Letting Go) / Mr. Talkbox Interlude"
# Song 3: "Angels We Have Heard on High"
# Song 4: "Atmosphere"
# Song 5: "Atmosphere [Ambiente Mix]"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Francesca Battiselli...
#
# Couldn't find Francesca Battiselli. Did you mean Francesca Battistelli? (y/n): y
# Song 1: "Angel By Your Side"
# Song 2: "Angel by Your Side (Unplugged)"
# Song 3: "Beautiful"
# Song 4: "Beautiful, Beautiful"
# Song 5: "Beautiful, Beautiful (Dented Fender Sessions)"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by MercyMe...
#
# Song 1: "3:42 am (Writers Block)"
# Song 2: "Adopted"
# Song 3: "Ain't No Rock"
# Song 4: "All Because Of This"
# Song 5: "All Fall Down"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Minor Threat...
#
# Song 1: "12XU"
# Song 2: "Betray"
# Song 3: "Bottled Violence"
# Song 4: "Bottled violence - version"
# Song 5: "Cashing In"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Black Flag...
#
# Song 1: "Account for What?"
# Song 2: "American Waste"
# Song 3: "Annihilate This Week"
# Song 4: "Armageddon Man"
# Song 5: "Bastard in Love"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Descendents...
#
# Song 1: "80's Girl"
# Song 2: "Ace"
# Song 3: "Alive"
# Song 4: "All"
# Song 5: "All-O-Gistics"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Fugazi...
#
# Song 1: "23 Beats Off"
# Song 2: "Afterthought"
# Song 3: "And the Same"
# Song 4: "And the Same - Demo"
# Song 5: "Argument"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Bad Brains...
#
# Song 1: "At the atlantis"
# Song 2: "At The Movies"
# Song 3: "Attitude"
# "Attitude - Instrumental" does not contain lyrics. Rejecting.
# Song 4: "Banned In D.C."
# Song 5: "Big Takeover"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Dead Kennedys...
#
# Song 1: "A Child & His Lawnmower"
# Song 2: "A Commercial"
# Song 3: "Advice From Christmas Past"
# Song 4: "A Growing Boy Needs His Lunch"
# Song 5: "Anarchy for Sale"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Rancid...
#
# Song 1: "1998"
# Song 2: "7 Years Down"
# Song 3: "Adina"
# Song 4: "All American Neighborhood"
# Song 5: "Already Dead"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Bad Religion...
#
# Song 1: "1000 Memories"
# Song 2: "1000 More Fools"
# Song 3: "10 in 2010"
# Song 4: "21st Century"
# Song 5: "21st Century (Digital Boy)"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by Pennywise...
#
# Song 1: "18 Soldiers"
# Song 2: "30 Seconds 'Till The End Of The World"
# Song 3: "6th Avenue Nightmare"
# Song 4: "Affliction"
# Song 5: "Alien"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# Searching for songs by NOFX...
#
# Song 1: "100 Times Fuckeder"
# Song 2: "13 Stitches"
# Song 3: "13 Stitches (acoustic)"
# Song 4: "180 Degrees"
# Song 5: "60%"
#
# Reached user-specified song limit (5).
# Found 5 songs.
# Done.
# [("[Verse 1]\nGood morning my love\nIt's been a while since we have talked\nAnd you have grown\nYour eyes are older than the tallest tree you see\nBecause thirty lives can be extraordinarily long\n\n[Chorus]\nLay me down, lay me down\nAgain my friend\nI know it's been a while since I could look you in the eyes\nBecause I am foolish and I am sorry\nBut sorry never made it feel alright, alright\n\n[Verse 2]\nGood morning myself\nIt's been a while since we have talked\nAnd you have changed\nFor better or worse is yet to determine\nBut I am sure\nThat you'll keep living and breathing until this world turns over\n\n[Chorus]\nLay me down, lay me down\nAgain my friend\nI know it's been a while since I could look you in the eyes\nBecause I am foolish and I am sorry\nBut sorry never made it feel alright, alright\nLay me down, lay me down\nAgain my friend\nI know it's been a while since I could look you in the eyes\nBecause I am foolish and I am sorry\nBut sorry never made it feel alright, alright", 'rock'), ("[Verse 1]\nGood morning, my love\nIt's been a while since we first talked\nAnd I have grown\nMy eyes are older than the tallest tree you see\nThirty lives can be extraordinarily long\n\n[Chorus]\nLay me down, lay me down\nAgain, my friend\nI know it's been a while since I could look you in the eye\nBut I am foolish and I am sorry\nAnd sorry never made it feel alright, alright\n\n[Verse 2]\nGood morning, myself\nIt's been a while since we have spoken\nAnd you have changed\nFor better or worse is yet to determine\nI am sure\nYou keep living and breathing until this world rolls over\n\n[Chorus]\nLay me down, lay me down\nAgain, my friend\nI know it's been a while since I could look you in the eye\nBut I am foolish and I am sorry\nAnd sorry never made it feel alright, alright\n\n[Bridge]\nStay with me, stay with me\nForever\n\n[Outro]\nAgain, my friend\nI know it's been a while since I could look you in the eye\nAnd I am foolish and I am sorry\nAbd sorry never made it feel alright, alright", 'rock'), ("[Verse 1]\nEverything you say is just a lie and now I'm leaving\nTo the city where the people are awake to chase a dream that isn't real\nAnd we're 'posed to be something that we're not\nJust wanna change a lot and sign our name after the dot\nEverything you see is just a century of anarchy\nAll my corresponding colors that symbolize the things we can attest\nArrange, we can assess, we can attain\nWe are the entry for entities to entice and entertain\n\n[Chorus]\nAll eyes, they're on you\nDon't deny, you've got to\nThis is a call, that's all you'll ever get from me\nThis is a call, that's all you'll ever get from me\n\n[Verse 2]\nTake my side\nTake my side, don't look back\nNow I'm easy and that's a fact\nAnd you're on my mind, oh\n\n[Pre-Chorus]\nEverything you say is just a lie and now I'm leaving\nTo the city where the people are awake to chase a dream that isn't real\nAnd we're 'posed to be something that we're not\nJust wanna change and sign our name after the dot\n\n[Chorus]\nAll eyes, they're on you\nDon't deny, you've got to\nThis is a call, that's all you'll ever get from me\n\n[Bridge]\nNow will the sun come up tonight?\nBecause your eyes they burn so bright\nI'm all you've got, when you say that you want it all\nYou want it all\n\n[Chorus]\nAll eyes, they're on you\nDon't deny, you've got to\nThis is a call, that's all you'll ever get from me\nThis is a call, that's all you'll ever get from me\nAll eyes, they're on you\nDon't deny, you've got to\nThis is a call, that's all you'll ever get from me\nThis is a call, that's all you'll ever get from me", 'rock'), ('[Verse 1]\nI get caught in the water, get torn in the wind\nI could drown in the river, while the sun burns dim\nI get tossed by the ocean, fall deep in the sand\nI’m drowned out by the thunder, lost in a laugh\n\n[Pre-Chorus]\nIs anyone listening?\nIs anyone around to see?\n\n[Chorus]\nThat I’m doing it all for you\nI’m doing it all for you\nI’m ready to go\nI’m ready  ...

# %%
output = pd.DataFrame(masterList)

# %%
output.to_csv('lyrics.csv')

# %%
import os 
print(os.getcwd())
# Out:
# /Users/andrewmckinnon2/Desktop/hack-nc-2018/scraping
